# %%
ls
# Out:
# Applications/                 Public/
# Desktop/                      Untitled.ipynb
# Documents/                    Untitled1.ipynb
# Downloads/                    Untitled2.ipynb
# Library/                      Untitled3.ipynb
# Movies/                       Untitled4.ipynb
# Music/                        opt/
# Pictures/                     weather_forecast-Copy1.ipynb
# Projects/                     weather_forecast.ipynb

# %%
cd Desktop
# Out:
# /Users/ashwinissac/Desktop

# %%
ls
# Out:
# Fruits Classification/     seattle-weather.csv
# Tesla.csv - Tesla.csv.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
sns.set()

# %%
stock = pd.read_csv('Tesla.csv - Tesla.csv.csv')
stock.head()
stock.set_index('Date', inplace=True)
stock
# Out:
#                  Open        High         Low       Close    Volume  \
# Date
# 6/29/2010   19.000000   25.000000   17.540001   23.889999  18766300
# 6/30/2010   25.790001   30.420000   23.299999   23.830000  17187100
# 7/1/2010    25.000000   25.920000   20.270000   21.959999   8218800
# 7/2/2010    23.000000   23.100000   18.709999   19.200001   5139800
# 7/6/2010    20.000000   20.000000   15.830000   16.110001   6866900
# ...               ...         ...         ...         ...       ...
# 3/13/2017  244.820007  246.850006  242.779999  246.169998   3010700
# 3/14/2017  246.110001  258.119995  246.020004  258.000000   7575500
# 3/15/2017  257.000000  261.000000  254.270004  255.729996   4816600
# 3/16/2017  262.399994  265.750000  259.059998  262.049988   7100400
# 3/17/2017  264.000000  265.329987  261.200012  261.500000   6475900
#
#             Adj Close
# Date
# 6/29/2010   23.889999
# 6/30/2010   23.830000
# 7/1/2010    21.959999
# 7/2/2010    19.200001
# ...

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
fig.suptitle('box plot for all fields')
sns.boxplot(ax=axes[0, 0], data=stock['Open'])
sns.boxplot(ax=axes[0, 1], data=stock['High'])
sns.boxplot(ax=axes[0, 2], data=stock['Low'])
sns.boxplot(ax=axes[1, 0], data=stock['Close'])
sns.boxplot(ax=axes[1, 1], data=stock['Volume'])
sns.boxplot(ax=axes[1, 2], data=stock['Adj Close'])
# Out:
# <AxesSubplot:>

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
fig.suptitle('box plot for all fields')
sns.lineplot(ax=axes[0, 0], data=stock['Open'])
sns.lineplot(ax=axes[0, 1], data=stock['High'])
sns.lineplot(ax=axes[0, 2], data=stock['Low'])
sns.lineplot(ax=axes[1, 0], data=stock['Close'])
sns.lineplot(ax=axes[1, 1], data=stock['Volume'])
sns.lineplot(ax=axes[1, 2], data=stock['Adj Close'])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Adj Close'>

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
fig.suptitle('scatter plot for all fields')
sns.scatterplot(ax=axes[0, 0], data=stock['Open'])
sns.scatterplot(ax=axes[0, 1], data=stock['High'])
sns.scatterplot(ax=axes[0, 2], data=stock['Low'])
sns.scatterplot(ax=axes[1, 0], data=stock['Close'])
sns.scatterplot(ax=axes[1, 1], data=stock['Volume'])
sns.scatterplot(ax=axes[1, 2], data=stock['Adj Close'])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Adj Close'>

# %%
r = stock['Volume'].quantile(0.9)
stock_1 = stock[stock['Volume'] < r]
stock_1
# Out:
#                  Open        High         Low       Close   Volume   Adj Close
# Date
# 7/1/2010    25.000000   25.920000   20.270000   21.959999  8218800   21.959999
# 7/2/2010    23.000000   23.100000   18.709999   19.200001  5139800   19.200001
# 7/6/2010    20.000000   20.000000   15.830000   16.110001  6866900   16.110001
# 7/7/2010    16.400000   16.629999   14.980000   15.800000  6921700   15.800000
# 7/8/2010    16.139999   17.520000   15.570000   17.459999  7711400   17.459999
# ...               ...         ...         ...         ...      ...         ...
# 3/13/2017  244.820007  246.850006  242.779999  246.169998  3010700  246.169998
# 3/14/2017  246.110001  258.119995  246.020004  258.000000  7575500  258.000000
# 3/15/2017  257.000000  261.000000  254.270004  255.729996  4816600  255.729996
# 3/16/2017  262.399994  265.750000  259.059998  262.049988  7100400  262.049988
# 3/17/2017  264.000000  265.329987  261.200012  261.500000  6475900  261.500000
#
# ...

# %%
r = stock_1['Open'].quantile(0.9)
stock_2 = stock_1[stock_1['Open'] < r]
stock_2
# Out:
#                  Open        High         Low       Close   Volume   Adj Close
# Date
# 7/1/2010    25.000000   25.920000   20.270000   21.959999  8218800   21.959999
# 7/2/2010    23.000000   23.100000   18.709999   19.200001  5139800   19.200001
# 7/6/2010    20.000000   20.000000   15.830000   16.110001  6866900   16.110001
# 7/7/2010    16.400000   16.629999   14.980000   15.800000  6921700   15.800000
# 7/8/2010    16.139999   17.520000   15.570000   17.459999  7711400   17.459999
# ...               ...         ...         ...         ...      ...         ...
# 3/8/2017   247.000000  250.070007  245.320007  246.869995  3725200  246.869995
# 3/9/2017   247.630005  248.660004  243.000000  244.899994  3861500  244.899994
# 3/10/2017  246.210007  246.500000  243.000000  243.690002  3057000  243.690002
# 3/13/2017  244.820007  246.850006  242.779999  246.169998  3010700  246.169998
# 3/14/2017  246.110001  258.119995  246.020004  258.000000  7575500  258.000000
#
# ...

# %%
r = stock_2['Close'].quantile(0.9)
stock_3 = stock_2[stock_2['Close'] < r]
stock_3
# Out:
#                  Open        High         Low       Close   Volume   Adj Close
# Date
# 7/1/2010    25.000000   25.920000   20.270000   21.959999  8218800   21.959999
# 7/2/2010    23.000000   23.100000   18.709999   19.200001  5139800   19.200001
# 7/6/2010    20.000000   20.000000   15.830000   16.110001  6866900   16.110001
# 7/7/2010    16.400000   16.629999   14.980000   15.800000  6921700   15.800000
# 7/8/2010    16.139999   17.520000   15.570000   17.459999  7711400   17.459999
# ...               ...         ...         ...         ...      ...         ...
# 1/5/2017   226.419998  227.479996  221.949997  226.750000  5911700  226.750000
# 1/6/2017   226.929993  230.309998  225.449997  229.009995  5527900  229.009995
# 1/10/2017  232.000000  232.000000  226.889999  229.869995  3660000  229.869995
# 1/11/2017  229.070007  229.979996  226.679993  229.729996  3650800  229.729996
# 1/12/2017  229.059998  230.699997  225.580002  229.589996  3790200  229.589996
#
# ...

# %%
r = stock_3['High'].quantile(0.9)
stock_4= stock_3[stock_2['High'] < r]
stock_4
# Out:
# /var/folders/5y/24pm91qs22b03yxy7hdqzrjh0000gn/T/ipykernel_8163/4215683025.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   stock_4= stock_3[stock_2['High'] < r]
#                   Open        High         Low       Close   Volume  \
# Date
# 7/1/2010     25.000000   25.920000   20.270000   21.959999  8218800
# 7/2/2010     23.000000   23.100000   18.709999   19.200001  5139800
# 7/6/2010     20.000000   20.000000   15.830000   16.110001  6866900
# 7/7/2010     16.400000   16.629999   14.980000   15.800000  6921700
# 7/8/2010     16.139999   17.520000   15.570000   17.459999  7711400
# ...                ...         ...         ...         ...      ...
# 12/22/2016  208.220001  209.990005  206.500000  208.449997  3111100
# 12/23/2016  208.000000  213.449997  207.710007  213.339996  4670500
# 12/29/2016  218.559998  219.199997  214.119995  214.679993  4045000
# 12/30/2016  216.300003  217.500000  211.679993  213.690002  4642600
# ...

# %%
r = stock_4['Low'].quantile(0.9)
stock_5 = stock_4[stock_4['Low'] < r]
stock_5
# Out:
#                   Open        High         Low       Close   Volume  \
# Date
# 7/1/2010     25.000000   25.920000   20.270000   21.959999  8218800
# 7/2/2010     23.000000   23.100000   18.709999   19.200001  5139800
# 7/6/2010     20.000000   20.000000   15.830000   16.110001  6866900
# 7/7/2010     16.400000   16.629999   14.980000   15.800000  6921700
# 7/8/2010     16.139999   17.520000   15.570000   17.459999  7711400
# ...                ...         ...         ...         ...      ...
# 12/14/2016  198.740005  203.000000  196.759995  198.690002  4150900
# 12/15/2016  198.410004  200.740005  197.389999  197.580002  3219600
# 12/16/2016  198.080002  202.589996  197.600006  202.490005  3796900
# 12/19/2016  202.490005  204.449997  199.839996  202.729996  3488100
# 12/20/2016  203.050003  209.000000  202.500000  208.789993  4689100
#
#              Adj Close
# Date
# 7/1/2010     21.959999
# 7/2/2010     19.200001
# 7/6/2010     16.110001
# 7/7/2010     15.800000
# ...

# %%
g, (x1,x3,x4) = plt.subplots(1,3, sharey=True, figsize=(15,3))
x1.scatter(stock_5['Open'],stock_5['Close'])
x1.set_title('Open and Close')
x3.scatter(stock_5['High'],stock_5['Close'])
x3.set_title('High and Close')
x4.scatter(stock_5['Low'],stock_5['Close'])
x4.set_title('Low and Close')
plt.show()

# %%
x = stock_5[['Open','High','Low','Volume']]
y = stock_5['Close']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size= 0.2)

# %%
x_train
# Out:
#                   Open        High         Low   Volume
# Date
# 3/23/2012    34.259998   34.630001   33.150002  1170600
# 9/6/2013    168.570007  169.699997  165.149994  8619700
# 1/21/2016   201.550003  203.229996  195.020004  3166200
# 12/10/2010   32.049999   32.919998   31.129999   429400
# 9/6/2011     22.500000   23.200001   22.290001   809800
# ...                ...         ...         ...      ...
# 6/27/2012    31.900000   32.450001   31.570000  1047200
# 3/29/2012    38.189999   38.189999   37.029999   796400
# 1/12/2015   203.050003  204.470001  199.250000  5950300
# 6/27/2011    27.730000   28.280001   27.309999  1809400
# 7/16/2012    34.320000   36.000000   33.900002  1744000
#
# [797 rows x 4 columns]

# %%
y_train
# Out:
# Date
# 3/23/2012      34.080002
# 9/6/2013      166.970001
# 1/21/2016     199.970001
# 12/10/2010     31.520000
# 9/6/2011       22.940001
#                  ...
# 6/27/2012      31.959999
# 3/29/2012      37.330002
# 1/12/2015     202.210007
# 6/27/2011      27.459999
# 7/16/2012      35.959999
# Name: Close, Length: 797, dtype: float64

# %%
x_test
# Out:
#                   Open        High         Low   Volume
# Date
# 2/19/2016   163.660004  167.490005  162.500000  2959400
# 2/6/2014    176.300003  180.110001  176.000000  5841600
# 4/8/2011     27.580000   27.600000   26.360001  1946400
# 8/17/2010    18.959999   19.400000   18.780001   447900
# 1/24/2014   177.850006  180.479996  173.529999  7664300
# ...                ...         ...         ...      ...
# 11/15/2011   32.919998   34.400002   32.730000   891000
# 4/8/2013     41.970001   42.549999   41.509998  1679000
# 11/15/2016  182.779999  186.429993  182.050003  3902000
# 8/10/2012    29.309999   29.940001   29.309999   707400
# 3/12/2015   193.750000  194.449997  189.750000  4149300
#
# [200 rows x 4 columns]

# %%
y_test
# Out:
# Date
# 2/19/2016     166.580002
# 2/6/2014      178.380005
# 4/8/2011       26.490000
# 8/17/2010      19.150000
# 1/24/2014     174.600006
#                  ...
# 11/15/2011     33.930000
# 4/8/2013       41.830002
# 11/15/2016    183.770004
# 8/10/2012      29.940001
# 3/12/2015     191.070007
# Name: Close, Length: 200, dtype: float64

# %%
reg = LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([-5.31224065e-01,  8.68143130e-01,  6.62251003e-01, -4.61392957e-08])

# %%
reg.intercept_
# Out:
# -0.022818260182773997

# %%
pred_1=reg.predict(x_train)
pred_1
# Out:
# array([ 33.74085519, 166.72566615, 198.34780161,  32.12678192,
#         22.88977367, 123.78320669,  26.5475625 ,  28.64175693,
#         28.48219744,  27.49524666,  35.13734797,  23.78371411,
#         25.05151805,  22.49279505,  23.40738484,  30.52966957,
#         24.87619138,  23.2858433 ,  28.13951721, 199.10173377,
#         24.33919314,  20.78915838,  33.0951678 ,  33.3063618 ,
#         35.1133147 ,  28.22737775,  29.41470125,  21.46628744,
#         20.37814039,  34.94753264,  29.41051207,  31.11130283,
#         30.39054667, 165.0867667 ,  36.51062936,  27.25735369,
#        172.57124261,  21.04403635,  28.52219718, 145.94911486,
#        199.42124379,  22.29083902, 196.47262291, 196.55078526,
#        189.33442689,  27.75331964, 101.3353091 ,  29.21293558,
#         35.2860753 ,  30.04292052,  29.47813177,  24.08655267,
#         26.38819167, 116.27245264,  21.24039648,  30.66344552,
#         29.91193426,  30.70995197,  18.95238391, 189.54421475,
# ...

# %%
prediction1 = pd.DataFrame({'Actual': y_train,'Prediction': pred_1})
prediction1
# Out:
#                 Actual  Prediction
# Date
# 3/23/2012    34.080002   33.740855
# 9/6/2013    166.970001  166.725666
# 1/21/2016   199.970001  198.347802
# 12/10/2010   31.520000   32.126782
# 9/6/2011     22.940001   22.889774
# ...                ...         ...
# 6/27/2012    31.959999   32.061327
# 3/29/2012    37.330002   37.330529
# 1/12/2015   202.210007  201.300330
# 6/27/2011    27.459999   27.800017
# 7/16/2012    35.959999   35.368568
#
# [797 rows x 2 columns]

# %%
sns.scatterplot( data=prediction1)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
pred_2=reg.predict(x_test)
pred_2
# Out:
# array([165.9215896 , 178.97028664,  26.65390398,  19.16355942,
#        176.74823763,  19.77860627,  31.36047934,  32.34692973,
#         37.60317845,  19.99280974,  33.20472899,  17.98976687,
#        204.22281308,  23.78330335,  20.68880672, 195.37358614,
#         28.75214704,  28.02296604,  24.98192073,  33.05036004,
#         32.13981087, 178.64486246, 177.17470462, 172.46001894,
#         20.58225138, 140.84304868,  33.73113241, 193.50381392,
#         20.98099129,  27.58555731,  33.22716149,  19.59460784,
#         33.09112072,  29.62498142,  29.05086128,  35.31580467,
#         27.77072866,  20.47373259,  30.35700599,  29.46680805,
#         37.81103048,  35.779234  ,  51.76328412,  27.96662828,
#         36.64771281,  27.3485002 ,  31.60398998,  23.84824815,
#        204.04945693, 206.71139307,  20.19896307,  31.42646366,
#        205.24356619,  26.25209659,  26.624623  ,  33.66743416,
#         30.43413425, 193.12420399,  22.99023363, 205.61229369,
# ...

# %%
prediction2 = pd.DataFrame({'Actual': y_test,'Prediction': pred_2})
prediction2
# Out:
#                 Actual  Prediction
# Date
# 2/19/2016   166.580002  165.921590
# 2/6/2014    178.380005  178.970287
# 4/8/2011     26.490000   26.653904
# 8/17/2010    19.150000   19.163559
# 1/24/2014   174.600006  176.748238
# ...                ...         ...
# 11/15/2011   33.930000   33.987777
# 4/8/2013     41.830002   42.033766
# 11/15/2016  183.770004  185.110727
# 8/10/2012    29.940001   29.777148
# 3/12/2015   191.070007  191.333630
#
# [200 rows x 2 columns]

# %%
sns.scatterplot( data=prediction2)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test,pred_2)
# Out:
# 0.562343501002416

# %%
from sklearn import metrics
import math
mean_absolute_error(y_train,pred_1)
# Out:
# 0.5782508463236573
